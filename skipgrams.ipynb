# %%
import sklearn

# %%
from sklearn.datasets import fetch_20newsgroups
from nltk.tokenize import sent_tokenize

# %%
categories = ['rec.motorcycles', 'comp.graphics', 'sci.med']
corpus = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=40,
                            remove=('headers', 'footers', 'quotes'))

# %%
from nltk.util import skipgrams
len(corpus)
# Out:
# 5

# %%
len(corpus['data'])
# Out:
# 1776

# %%
corpus['data']
# Out:
# [': Concerning the proposed newsgroup split, I personally am not in favor of\n: doing this.  I learn an awful lot about all aspects of graphics by reading\n: this group, from code to hardware to algorithms.  I just think making 5\n: different groups out of this is a wate, and will only result in a few posts\n: a week per group.  I kind of like the convenience of having one big forum\n: for discussing all aspects of graphics.  Anyone else feel this way?\n: Just curious.\n\n\n: Daemon\n\nWhat he said...\n\n-- ',
#  'Does anybody out there have or know how to calculate the RGB values \nrequired to set the 256 color VGA palette so that the colors from \n0..255 will give 256 colors  of the rainbow ie red, orange, \nyellow, etc.\n\nAny help would be appreciated. Please email to eeerik@cc.newcastle.edu.au',
# ...

# %%
sentence_list = []
for post in corpus['data']:
    sent_tokenize_list = sent_tokenize(post)
    sentence_list.extend(sent_tokenize_list)

# %%
from nltk.tokenize import word_tokenize
word_tokenize(sentence_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d71e11f75a2c> in <module>()
#       1 from nltk.tokenize import word_tokenize
# ----> 2 word_tokenize(sentence_list)
#
# /anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# /anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ...

# %%
word_list =[]
for sent in sentence_list:
    word_tokenize(sent)
    word_list.append(word_tokenize(sent))

# %%
word_list
# Out:
# [[':',
#   'Concerning',
#   'the',
#   'proposed',
#   'newsgroup',
#   'split',
#   ',',
#   'I',
#   'personally',
#   'am',
#   'not',
#   'in',
#   'favor',
#   'of',
#   ':',
#   'doing',
#   'this',
#   '.'],
#  ['I',
#   'learn',
#   'an',
#   'awful',
#   'lot',
#   'about',
#   'all',
#   'aspects',
#   'of',
#   'graphics',
#   'by',
#   'reading',
#   ':',
#   'this',
#   'group',
#   ',',
#   'from',
#   'code',
#   'to',
#   'hardware',
#   'to',
#   'algorithms',
#   '.'],
#  ['I',
#   'just',
#   'think',
#   'making',
#   '5',
#   ':',
#   'different',
#   'groups',
#   'out',
#   'of',
#   'this',
#   'is',
#   'a',
#   'wate',
#   ',',
#   'and',
#   'will',
#   'only',
#   'result',
#   'in',
#   'a',
#   'few',
#   'posts',
#   ':',
#   'a',
#   'week',
#   'per',
#   'group',
#   '.'],
#  ['I',
#   'kind',
#   'of',
#   'like',
#   'the',
#   'convenience',
#   'of',
#   'having',
#   'one',
#   'big',
#   'forum',
#   ':',
#   'for',
#   'discussing',
# ...
